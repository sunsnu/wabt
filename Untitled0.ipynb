# %% [markdown]
# <a href="https://colab.research.google.com/github/sunsnu/wabt/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.8.1
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.1
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.1.0
# ...

# %%
import torch
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.6.0+cu124  Device: cuda

# %%
torch.tensor([1,2,3]) +10
# Out:
# tensor([11, 12, 13])

# %%
from IPython.display import Image as IPythonImage
IPythonImage(url='https://raw.githubusercontent.com/rickiepark/ml-with-pytorch/main/ch12/figures/12_02.png', width=500)
# Out:
# <img src="https://raw.githubusercontent.com/rickiepark/ml-with-pytorch/main/ch12/figures/12_02.png" width="500"/>

# %%
import torch
from torch.utils.data import DataLoader
t= torch.arange(6, dtype=torch.float32)

# %%
t
# Out:
# tensor([0., 1., 2., 3., 4., 5.])

# %%
dataloader =  DataLoader(t)

# %%
for item in dataloader :
  print(item)
# Out:
# tensor([0.])
# tensor([1.])
# tensor([2.])
# tensor([3.])
# tensor([4.])
# tensor([5.])

# %%
from torch.utils.data import Dataset
class JoinDataset(Dataset):
  def __init__(self,x,y) :
    self.x = x
    self.y = y
  def __len__(self) :
    return len(self.x)
  def __getitem__(self,idx) :
    return self.x[idx], self.y[idx]

# %%
a=[1,2,3]
print(a.__len__())
print(a.__getitem__(1))
# Out:
# 3
# 2

# %%
torch.manual_seed(42)

X = torch.rand([4,3])
y= torch.arange(4)

# %%
join_dataset = JoinDataset(X,y)

# %%
X
# Out:
# tensor([[0.8823, 0.9150, 0.3829],
#         [0.9593, 0.3904, 0.6009],
#         [0.2566, 0.7936, 0.9408],
#         [0.1332, 0.9346, 0.5936]])

# %%
join_dataset[1]
# Out:
# (tensor([0.9593, 0.3904, 0.6009]), tensor(1))

# %%
# !wget https://github.com/rickiepark/ml-with-pytorch/raw/main/ch12/cat_dog_images.tar.gz
# Out:
# --2025-06-27 07:36:14--  https://github.com/rickiepark/ml-with-pytorch/raw/main/ch12/cat_dog_images.tar.gz
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rickiepark/ml-with-pytorch/main/ch12/cat_dog_images.tar.gz [following]
# --2025-06-27 07:36:14--  https://raw.githubusercontent.com/rickiepark/ml-with-pytorch/main/ch12/cat_dog_images.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 965517 (943K) [application/octet-stream]
# Saving to: ‘cat_dog_images.tar.gz’
#
# cat_dog_images.tar. 100%[===================>] 942.89K  --.-KB/s    in 0.009s
#
# ...

# %%
# !ls -al
# Out:
# total 960
# drwxr-xr-x 1 root root   4096 Jun 27 07:36 .
# drwxr-xr-x 1 root root   4096 Jun 27 07:27 ..
# -rw-r--r-- 1 root root 965517 Jun 27 07:36 cat_dog_images.tar.gz
# drwxr-xr-x 4 root root   4096 Jun 25 13:36 .config
# drwxr-xr-x 1 root root   4096 Jun 25 13:36 sample_data

# %%
# !tar -xvzf cat_dog_images.tar.gz
# Out:
# cat_dog_images/
# cat_dog_images/dog-02.jpg
# cat_dog_images/dog-03.jpg
# cat_dog_images/dog-01.jpg
# cat_dog_images/cat-02.jpg
# cat_dog_images/cat-03.jpg
# cat_dog_images/cat-01.jpg

# %%
import pathlib


imgdir_path = pathlib.Path('cat_dog_images')


file_list = sorted([str(path) for path in imgdir_path.glob('*.jpg')])


print(file_list)
# Out:
# ['cat_dog_images/cat-01.jpg', 'cat_dog_images/cat-02.jpg', 'cat_dog_images/cat-03.jpg', 'cat_dog_images/dog-01.jpg', 'cat_dog_images/dog-02.jpg', 'cat_dog_images/dog-03.jpg']

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image




fig = plt.figure(figsize=(10, 5))
for i, file in enumerate(file_list):
    img = Image.open(file)
    print('Image shape: ', np.array(img).shape)
    ax = fig.add_subplot(2, 3, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(img)
    ax.set_title(os.path.basename(file), size=15)


#plt.savefig('figures/12_03.pdf')
plt.tight_layout()
plt.show()
# Out:
# Image shape:  (900, 1200, 3)
# Image shape:  (900, 1200, 3)
# Image shape:  (900, 742, 3)
# Image shape:  (800, 1200, 3)
# Image shape:  (800, 1200, 3)
# Image shape:  (900, 1200, 3)

# %%
labels = [1 if 'dog' in os.path.basename(file) else 0
          for file in file_list]
print(labels)
# Out:
# [0, 0, 0, 1, 1, 1]

# %%
class ImageDataset(Dataset):
    def __init__(self, file_list, labels):
        self.file_list = file_list
        self.labels = labels


    def __getitem__(self, index):
        file = self.file_list[index]
        label = self.labels[index]
        return file, label


    def __len__(self):
        return len(self.labels)

# %%
img_dataset = ImageDataset(file_list, labels)

# %%
import torchvision

# %%
mnist_dataset = torchvision.datasets.MNIST("./mnist", 'train', download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.03MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 132kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.07MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.85MB/s]

# %%
examples = next(iter(mnist_dataset))

# %%
print(examples)
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x7BE6509043D0>, 5)

# %%
import matplotlib.pyplot as plt
from itertools import islice
fig = plt.figure(figsize=(15, 6))
for i, (image, label) in islice(enumerate(mnist_dataset), 10):
    ax = fig.add_subplot(2, 5, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(image, cmap='gray_r')
    ax.set_title(f'{label}', size=15)


#plt.savefig('figures/12_06.pdf')
plt.show()

# %%
from torchvision import transforms
train_dataset = torchvision.datasets.MNIST("./data/MNIST", train=True, download=True, transform=transforms.ToTensor())
test_dataset = torchvision.datasets.MNIST("./data/MNIST", train=False, download=True, transform=transforms.ToTensor())
# Out:
# 100%|██████████| 9.91M/9.91M [00:11<00:00, 895kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 63.5kB/s]
# 100%|██████████| 1.65M/1.65M [00:06<00:00, 238kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.52MB/s]

# %%
import torch

torch.utils.data.DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size= 32, shuffle=True)

# %%
for  X_train, y_train   in train_loader:
  print('x_train : ', X_train.size())
  print('y_train : ', y_train.shape)
  print(y_train)
  break
  # torch.Size 안의 [이미지의 수, 흑백/칼라 여부, 크기, 크기]
# Out:
# x_train :  torch.Size([32, 1, 28, 28])
# y_train :  torch.Size([32])
# tensor([3, 7, 3, 1, 7, 3, 4, 4, 8, 1, 7, 6, 8, 8, 6, 4, 6, 9, 4, 8, 0, 5, 7, 4,
#         9, 3, 0, 0, 1, 7, 6, 7])

# %%
# 0이 많은 행렬 희소행렬

# %%
import torch.nn as nn

# %%
# DNN(Deep Neural Network)
# 완전 연결층
import torch.nn.functional as F
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(28 * 28, 512)
    self.fc2 = nn.Linear(512, 256)
    self.fc3 = nn.Linear(256, 10)
    self.dropout_prob = 0.5
    self.batch_norm1 = nn.BatchNorm1d(512)
    self.batch_norm2 = nn.BatchNorm1d(256)


  def forward(self, x ):
    x = x.view(-1, 28 * 28)
    x = self.fc1(x)
    x = self.batch_norm1(x)
    x = F.relu(x) # 활성화 함수
    x = F.dropout(x, p= self.dropout_prob, training=self.training)
    x = self.fc2(x)
    x = self.batch_norm2(x)
    x = F.relu(x)
    x = F.dropout(x, p= self.dropout_prob, training=self.training)
    x = self.fc3(x)
    x = F.log_softmax(x)
    return x

# %%
model = Net().to(DEVICE)

# %%
pip install torchinfo

# %%
from torchinfo import summary

# %%
401920 - 28*28*512
# 401920 - 28*28*512 = 512
# 계산한 값과 차이는 파라미터에 해당하는 bias(512, 256, 10 등) 값임!
# Out:
# 512

# %%
summary(model)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# Net                                      --
# ├─Linear: 1-1                            401,920
# ├─Linear: 1-2                            131,328
# ├─Linear: 1-3                            2,570
# ├─BatchNorm1d: 1-4                       1,024
# ├─BatchNorm1d: 1-5                       512
# ...
# Total params: 537,354
# Trainable params: 537,354
# Non-trainable params: 0
# ...

# %%
criterion = nn.CrossEntropyLoss()

def train(model, train_loader,optimizer, log_interval) :
  model.train()

  for batch_idx, (image,label)  in enumerate(train_loader) :
    optimizer.zero_grad() # 기울기 초기화
    output = model(image)
    loss = criterion(output, label) # 엔트로피가 낮아야 좋음
    loss.backward() # 합성함수 미분
    optimizer.step() # 업데이트

    if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))

# %%
BATCH_SIZE = 32
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0


    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()


    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
# SGD : 확률적 경사 하강법

# %%
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size= 32, shuffle=True)

# %%
EPOCHS = 10
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-65-1954337603.py in <cell line: 0>()
#       1 EPOCHS = 10
#       2 for epoch in range(1, EPOCHS + 1):
# ----> 3     train(model, train_loader, optimizer, log_interval = 200)
#       4     test_loss, test_accuracy = evaluate(model, test_loader)
#       5     print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
#
# /tmp/ipython-input-60-1843773907.py in train(model, train_loader, optimizer, log_interval)
#       6   for batch_idx, (image,label)  in enumerate(train_loader) :
#       7     optimizer.zero_grad() # 기울기 초기화
# ----> 8     output = model(image)
#       9     loss = criterion(output, label) # 엔트로피가 낮아야 좋음
#      10     loss.backward() # 합성함수 미분
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
# ...
